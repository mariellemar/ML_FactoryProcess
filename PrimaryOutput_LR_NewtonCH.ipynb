# %%
import pandas as pd
import matplotlib.pyplot as plt
# import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report, confusion_matrix

# %%
data = pd.read_csv('dataset\continuous_factory_process.csv')
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\vinic\AppData\Local\Temp\ipykernel_11292\1729752437.py:1: SyntaxWarning: invalid escape sequence '\c'
#   data = pd.read_csv('dataset\continuous_factory_process.csv')
#             time_stamp  AmbientConditions.AmbientHumidity.U.Actual  \
# 0  2019-03-06 10:52:33                                       17.24
# 1  2019-03-06 10:52:34                                       17.24
# 2  2019-03-06 10:52:35                                       17.24
# 3  2019-03-06 10:52:36                                       17.24
# 4  2019-03-06 10:52:37                                       17.24
#
#    AmbientConditions.AmbientTemperature.U.Actual  \
# 0                                          23.53
# 1                                          23.53
# 2                                          23.53
# 3                                          23.53
# ...

# %%
cleaned_data = data.dropna()
cleaned_data.head()
# Out:
#             time_stamp  AmbientConditions.AmbientHumidity.U.Actual  \
# 0  2019-03-06 10:52:33                                       17.24
# 1  2019-03-06 10:52:34                                       17.24
# 2  2019-03-06 10:52:35                                       17.24
# 3  2019-03-06 10:52:36                                       17.24
# 4  2019-03-06 10:52:37                                       17.24
#
#    AmbientConditions.AmbientTemperature.U.Actual  \
# 0                                          23.53
# 1                                          23.53
# 2                                          23.53
# 3                                          23.53
# 4                                          23.53
#
#    Machine1.RawMaterial.Property1  Machine1.RawMaterial.Property2  \
# 0                           11.54                             200
# 1                           11.54                             200
# ...

# %%
#Features: Raw materials, process vars, combiner stage
features_columns = list(range(3, 39)) + list(range(39, 42))
features = cleaned_data.iloc[:, features_columns]

# %%
#Targets: Primary output measurements, setpoints
target_columns = list(range(42, 71))
targets = cleaned_data.iloc[:, target_columns]

# %%
features.head()
targets.head()
# Out:
#    Stage1.Output.Measurement0.U.Actual  Stage1.Output.Measurement0.U.Setpoint  \
# 0                                12.72                                  13.75
# 1                                12.34                                  13.75
# 2                                12.34                                  13.75
# 3                                12.34                                  13.75
# 4                                12.29                                  13.75
#
#    Stage1.Output.Measurement1.U.Actual  Stage1.Output.Measurement1.U.Setpoint  \
# 0                                  0.0                                  22.74
# 1                                  0.0                                  22.74
# 2                                  0.0                                  22.74
# 3                                  0.0                                  22.74
# 4                                  0.0                                  22.74
#
# ...

# %%
tolerance = 0.05
binary_labels = pd.DataFrame()

# %%
for i in range(0, targets.shape[1]-1, 2):
    actual = targets.iloc[:, i]
    setpoint = targets.iloc[:, i + 1]
    within_tolerance = (
        (actual - setpoint).abs()
        <=
        (tolerance * setpoint)).astype(int)
    binary_labels[f'Label_{i//2+1}'] = within_tolerance

# %%
target_labels = binary_labels.iloc[:, 0]

# %% [markdown]
# #### Conjunto de Validação (60% treino 20% validação 20% teste) - Classificador: Newton-Cholesky

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target_labels, test_size=0.4, random_state=42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.5, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.fit_transform(X_val)
X_test_scaled = scaler.fit_transform(X_test)

# %%
log_model = LogisticRegression(solver='newton-cholesky', max_iter=1000)
log_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='newton-cholesky')

# %%
y_val_pred = log_model.predict(X_val_scaled)

# %%
y_pred = log_model.predict(X_test_scaled)

# %%
class_labels = ['out of tolerance', 'within tolerance']

# %%
val_accuracy = accuracy_score(y_val, y_val_pred)
val_precision = precision_score(y_val, y_val_pred)
val_recall = recall_score(y_val, y_val_pred)
val_f1_score = f1_score(y_val, y_val_pred)

val_report = classification_report(y_val, y_val_pred, target_names=class_labels)

test_accuracy = accuracy_score(y_test, y_pred)
test_precision = precision_score(y_test, y_pred)
test_recall = recall_score(y_test, y_pred)
test_f1_score = f1_score(y_test, y_pred)

test_report = classification_report(y_test, y_pred, target_names=class_labels)

test_conf_matrix = confusion_matrix(y_test, y_pred)

# %%
print(val_report)
# Out:
#                   precision    recall  f1-score   support
#
# out of tolerance       0.90      0.95      0.93      3428
# within tolerance       0.72      0.56      0.63       798
#
#         accuracy                           0.88      4226
#        macro avg       0.81      0.75      0.78      4226
#     weighted avg       0.87      0.88      0.87      4226

# %%
print(test_report)
# Out:
#                   precision    recall  f1-score   support
#
# out of tolerance       0.90      0.95      0.92      4505
# within tolerance       0.74      0.56      0.64      1131
#
#         accuracy                           0.87      5636
#        macro avg       0.82      0.76      0.78      5636
#     weighted avg       0.86      0.87      0.87      5636

# %%
print('Acurácia do Teste: {:.2f}%'.format(test_accuracy * 100))
print('Precisão do Teste: {:.2f}%'.format(test_precision * 100))
print('Recall do Teste: {:.2f}%'.format(test_recall * 100))
print('F1-score do Teste: {:.2f}%'.format(test_f1_score * 100))
# Out:
# Acurácia do Teste: 87.24%
# Precisão do Teste: 74.12%
# Recall do Teste: 55.97%
# F1-score do Teste: 63.78%

# %%
print('Acurácia da Validação: {:.2f}%'.format(val_accuracy * 100))
print('Precisão da Validação: {:.2f}%'.format(val_precision * 100))
print('Recall da Validação: {:.2f}%'.format(val_recall * 100))
print('F1-score da Validação: {:.2f}%'.format(val_f1_score * 100))
# Out:
# Acurácia da Validação: 87.58%
# Precisão da Validação: 71.98%
# Recall da Validação: 56.02%
# F1-score da Validação: 63.00%

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)

plt.title('Confusion Matrix - Logistic Regression')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# #### Conjunto de Validação (50% treino 25% validação 25% teste) - Classificador: Newton-Cholesky

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target_labels, test_size=0.5, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.5, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.fit_transform(X_val)
X_test_scaled = scaler.fit_transform(X_test)

log_model = LogisticRegression(solver='newton-cholesky', max_iter=1000)
log_model.fit(X_train_scaled, y_train)

y_val_pred = log_model.predict(X_val_scaled)
y_pred = log_model.predict(X_test_scaled)

class_labels = ['out of tolerance', 'within tolerance']

# %%
val_accuracy = accuracy_score(y_val, y_val_pred)
val_precision = precision_score(y_val, y_val_pred)
val_recall = recall_score(y_val, y_val_pred)
val_f1_score = f1_score(y_val, y_val_pred)

val_report = classification_report(y_val, y_val_pred, target_names=class_labels)

test_accuracy = accuracy_score(y_test, y_pred)
test_precision = precision_score(y_test, y_pred)
test_recall = recall_score(y_test, y_pred)
test_f1_score = f1_score(y_test, y_pred)

test_report = classification_report(y_test, y_pred, target_names=class_labels)

test_conf_matrix = confusion_matrix(y_test, y_pred)

# %%
print(val_report)
# Out:
#                   precision    recall  f1-score   support
#
# out of tolerance       0.89      0.95      0.92      2854
# within tolerance       0.73      0.52      0.60       668
#
#         accuracy                           0.87      3522
#        macro avg       0.81      0.74      0.76      3522
#     weighted avg       0.86      0.87      0.86      3522

# %%
print(test_report)
# Out:
#                   precision    recall  f1-score   support
#
# out of tolerance       0.89      0.96      0.92      5651
# within tolerance       0.75      0.51      0.60      1393
#
#         accuracy                           0.87      7044
#        macro avg       0.82      0.73      0.76      7044
#     weighted avg       0.86      0.87      0.86      7044

# %%
print('Acurácia do Teste: {:.2f}%'.format(test_accuracy * 100))
print('Precisão do Teste: {:.2f}%'.format(test_precision * 100))
print('Recall do Teste: {:.2f}%'.format(test_recall * 100))
print('F1-score do Teste: {:.2f}%'.format(test_f1_score * 100))
# Out:
# Acurácia do Teste: 86.93%
# Precisão do Teste: 75.16%
# Recall do Teste: 50.61%
# F1-score do Teste: 60.49%

# %%
print('Acurácia da Validação: {:.2f}%'.format(val_accuracy * 100))
print('Precisão da Validação: {:.2f}%'.format(val_precision * 100))
print('Recall da Validação: {:.2f}%'.format(val_recall * 100))
print('F1-score da Validação: {:.2f}%'.format(val_f1_score * 100))
# Out:
# Acurácia da Validação: 87.17%
# Precisão da Validação: 72.69%
# Recall da Validação: 51.80%
# F1-score da Validação: 60.49%

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)

plt.title('Confusion Matrix - Logistic Regression')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
